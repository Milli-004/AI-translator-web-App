# %% [markdown]
# <a href="https://colab.research.google.com/github/Milli-004/AI-translator-web-App/blob/main/translation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome in google colab')
# Out:
# Welcome in google colab

# %%
#Create language translation using hugging face from transformers

from transformers import MarianMTModel, MarianTokenizer
#to select the model name from hugging face transformers
model_name = 'Helsinki-NLP/opus-mt-en-hi'

#to load the model using model name
model = MarianMTModel.from_pretrained(model_name)

#to load the tokenizer using model name
tokenizer = MarianTokenizer.from_pretrained(model_name)

#to get the input text from user to translate
input_text = input('Enter the text to translate: ')

#to encode the input text into input tokens using tokenizers
input_tokens = tokenizer(input_text, return_tensors='pt', padding= True)

#to generate the output tokens using model and input tokens
output_tokens = model.generate(**input_tokens)

#to decode the output tokens into translated text
translated_text = tokenizer.decode(output_tokens[0], skip_special_tokens=True)

#to print the translated text
print('Translated text: ', translated_text)


#upload the code to github
