# %% [markdown]
# <a href="https://colab.research.google.com/github/Milli-004/AI-translator-web-App/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#speech to text convert using whisper model
# !pip install openai-whisper
# !apt install -y ffmpeg

import whisper
from google.colab import files

model = whisper.load_model("base")

uploaded = files.upload()
audio = list(uploaded.keys())[0]

result = model.transcribe(audio, fp16 = False)
print(result["text"])
